# %% [markdown]
# # **JUDUL**
#
# ### Analisis Kinerja Keuangan Perusahaan Terdaftar Di Bursa Efek (IDX)

# %% [markdown]
# # **Import Liberary**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Memuat Dataset**

# %%
paht ="/content/drive/MyDrive/checkpoint ke 2/combined_financial_data_idx.csv"
df = pd.read_csv(paht)
df
# Out:
#       symbol                                     account type          2020  \
# 0       AALI                            Accounts Payable   BS  7.702640e+11
# 1       AALI                         Accounts Receivable   BS  7.658490e+11
# 2       AALI                    Accumulated Depreciation   BS -1.092095e+13
# 3       AALI                  Additional Paid In Capital   BS  3.878995e+12
# 4       AALI  Allowance For Doubtful Accounts Receivable   BS -2.426100e+10
# ...      ...                                         ...  ...           ...
# 89238   ZINC                         Total Unusual Items   IS  2.459341e+09
# 89239   ZINC      Total Unusual Items Excluding Goodwill   IS  2.459341e+09
# 89240   ZINC         Tradeand Other Payables Non Current   BS  1.542456e+11
# 89241   ZINC                             Work In Process   BS  3.757703e+08
# 89242   ZINC                             Working Capital   BS  5.365589e+10
#
#                2021          2022          2023
# 0      1.026717e+12  1.224423e+12  8.420640e+11
# 1      4.581350e+11  8.487700e+11  6.744870e+11
# 2     -1.213381e+13 -1.330375e+13 -1.443685e+13
# 3      3.878995e+12  3.878995e+12  3.878995e+12
# 4     -2.454300e+10 -2.705700e+10 -2.651600e+10
# ...             ...           ...           ...
# 89238  1.096695e+10  7.474979e+08  8.117474e+07
# 89239  1.096695e+10  7.474979e+08  8.117474e+07
# 89240  3.418800e+09  3.418800e+09  3.418800e+09
# 89241  3.757703e+08  3.874522e+09  7.067292e+10
# 89242  4.599091e+11 -3.023633e+10  1.285367e+11
#
# [89243 rows x 7 columns]
# Warning: total number of rows (89243) exceeds max_rows (20000). Limiting to first (20000) rows.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %% [markdown]
# bang saya hanya menampilakan hanya 25 di datasetnya saolnya ada max_rows(20000) jadi nanti di hapus aja headnya

# %% [markdown]
# # **Business Understanding**
# ### A. Business Objective
#  Dataset yang digunakan merupakan data laporan keuangan perusahaan yang terdaftar di Bursa Efek Indonesia (IDX) yang memuat beberapa variabel keuangan utama seperti Revenue, Net Income, Total Assets, dan Total Liabilities Data ini dapat digunakan untuk menggambarkan kondisi kinerja dan kesehatan finansial perusahaan Permasalahan yang dapat diangkat dari dataset ini adalah bagaimana mengetahui tingkat profitabilitas perusahaan, bagaimana struktur keuangan perusahaan berdasarkan utang dan aset, serta apakah perusahaan dengan ukuran besar selalu memiliki performa yang lebih baik dibandingkan perusahaan lainnya
#
# ### B. Assess Situation
# Dataset ini terdiri dari lebih dari 1000 baris data dengan beberapa variabel numerik utama yang relevan untuk analisis keuangan Tantangan yang mungkin dihadapi dalam dataset ini antara lain adanya perbedaan skala nilai antar perusahaan yang cukup besar, kemungkinan terdapat nilai ekstrem (outlier), serta perlunya pembuatan rasio keuangan agar data lebih mudah dianalisis Selain itu dataset ini hanya berfokus pada data keuangan dan tidak mencakup faktor eksternal seperti kondisi ekonomi atau kebijakan industri yang dapat memengaruhi kinerja perusahaan
#
# ### C. Analytic Goals & Project Plan
# ### Goals
# Untuk menjawab permasalahan tersebut analisis yang akan dilakukan meliputi analisis deskriptif terhadap Revenue dan Net Income, perhitungan rasio keuangan seperti Profit Margin dan Debt Ratio, serta analisis hubungan antara Total Assets, Revenue, dan Net Income Analisis ini bertujuan untuk mengidentifikasi pola kinerja perusahaan serta memahami hubungan antar variabel keuangan yang ada dalam dataset
# ### Project plan
# Rencana yang akan dilakukan dalam proyek ini dimulai dengan memahami struktur dataset dan melakukan pengecekan terhadap tipe data serta kemungkinan missing value Selanjutnya dilakukan pengolahan data dengan membuat variabel turunan berupa rasio keuangan Setelah itu dilakukan analisis deskriptif dan visualisasi data untuk melihat pola distribusi dan hubungan antar variabel Tahap akhir adalah menarik insight berdasarkan hasil analisis yang telah dilakukan

# %% [markdown]
# # **Checkpoint 2**

# %% [markdown]
# ## **Struktur Data**

# %% [markdown]
# ### **Informasi dasar**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89243 entries, 0 to 89242
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   symbol   89243 non-null  object
#  1   account  89243 non-null  object
#  2   type     89243 non-null  object
#  3   2020     83988 non-null  float64
#  4   2021     84474 non-null  float64
#  5   2022     83634 non-null  float64
#  6   2023     69831 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 4.8+ MB

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 89243 Baris dan 7 Kolom

# %% [markdown]
# ### **Informasi lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89243 entries, 0 to 89242
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   symbol   89243 non-null  object
#  1   account  89243 non-null  object
#  2   type     89243 non-null  object
#  3   2020     83988 non-null  float64
#  4   2021     84474 non-null  float64
#  5   2022     83634 non-null  float64
#  6   2023     69831 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 4.8+ MB

# %% [markdown]
# 1. symblo: 0
#         Jumlah baris: 89243
#         Tipe data: object
#         Deskripsi: ID utama Perusahaan
#
# 2. account:
#         Jumlah baris: 89243
#         Tipe data: object
#         Deskripsi: Nama akun keuangan perusahaan
#
# 3. type:
#         Jumlah baris: 89243
#         Tipe data: object
#         Deskripsi: Jenis laporan keuangan
#
# 4. 2020:
#         Jumlah baris: 89243
#         Tipe data: float64
#         Deskripsi: Nilai laporan keuangan tahun 2020
#
# 5. 2021:
#         Jumlah baris: 89243
#         Tipe data: float64
#         Deskripsi: Nilai laporan keuangan tahun 2021
#
# 6. 2022:
#         Jumlah baris: 89243
#         Tipe data: float64
#         Deskripsi: Nilai laporan keuangan tahun 2022
#
# 7. 2023:
#         Jumlah baris: 89243
#         Tipe data: float64
#         Deskripsi: Nilai laporan keuangan tahun 2023

# %% [markdown]
# ## **Informasi Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#        symbol            account   type          2020          2021  \
# count   89243              89243  89243  8.398800e+04  8.447400e+04
# unique    604                264      3           NaN           NaN
# top      TLKM  Total Tax Payable     BS           NaN           NaN
# freq      199                604  38675           NaN           NaN
# mean      NaN                NaN    NaN  1.197697e+12  1.399118e+12
# std       NaN                NaN    NaN  1.532871e+13  1.717454e+13
# min       NaN                NaN    NaN -4.127934e+14 -4.826358e+14
# 25%       NaN                NaN    NaN  0.000000e+00  1.648572e-01
# 50%       NaN                NaN    NaN  6.334818e+09  7.411000e+09
# 75%       NaN                NaN    NaN  2.220000e+11  2.609188e+11
# max       NaN                NaN    NaN  1.610065e+15  1.725611e+15
#
#                 2022          2023
# count   8.363400e+04  6.983100e+04
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean    1.497669e+12  1.714984e+12
# std     1.889606e+13  2.166294e+13
# min    -5.610016e+14 -5.709176e+14
# 25%     3.511105e-01  8.170234e+04
# 50%     8.395047e+09  1.168128e+10
# 75%     2.965390e+11  3.485207e+11
# max     1.992545e+15  2.174219e+15

# %% [markdown]
# 1. **Count (Kelengkapan Data)** Berdasarkan data, total baris data adalah 89.243. Maka dapat disimpulkan:
#
# * Kolom 2020 memiliki 83.988 data hilang 5.255 data
#
# * Kolom 2021 memiliki 84.474 data hilang 4.769 data
#
# * Kolom 2022 memiliki 83.634 data hilang 5.609 data
#
# * Kolom 2023 memiliki 69.831 data hilang 19.412 data
#
# **Kesimpulan:**
# Kolom tahun (2020–2023) mengandung missing values, terutama pada tahun 2023 yang memiliki data kosong paling banyak, sedangkan kolom identitas perusahaan dan akun sudah lengkap
#
# ---
#
# 2. **Mean vs Median (Distribusi Data)**
#
# * Kolom 2020
#
#   * Mean ≈ 1.197.697.159.647
#
#    * Median ≈ 6.334.818.263
# Rata-rata jauh lebih besar dari median, menunjukkan adanya nilai ekstrem sangat tinggi
#
# * Kolom 2021
#
#    * Mean ≈ 1.399.118.238.439
#
#    * Median ≈ 7.411.000.000
# Perbedaan besar antara mean dan median menandakan distribusi condong ke kanan
#
# * Kolom 2022
#
#   * Mean ≈ 1.497.669.192.586
#
#   * Median ≈ 8.395.046.739
# Nilai rata-rata meningkat dan tetap jauh di atas median, menandakan dominasi nilai besar pada beberapa perusahaan
#
# * Kolom 2023
#
#    * Mean ≈ 1.714.983.705.101
#
#    * Median ≈ 11.681.277.308
# Selisih yang sangat signifikan menunjukkan banyak data dengan nilai sangat tinggi yang menarik rata-rata ke atas
#
# **Kesimpulan:**
# Secara keseluruhan, data keuangan bersifat right-skewed condong ke kanan karena terdapat beberapa nilai laporan keuangan yang sangat besar dibanding mayoritas data
#
# ---
#
# 3. **Min dan Max (Validasi Logika Data)**
#
# * Tahun 2020
#
#   * Min = -4.127.934.140.000.000
#
#   * Max = 1.610.065.344.000.000
#
# * Tahun 2021
#
#   * Min = -4.826.358.420.000.000
#
#   * Max = 1.725.611.128.000.000
#
# * Tahun 2022
#
#   * Min = -5.610.016.210.000.000
#
#   * Max = 1.992.544.687.000.000
#
# * Tahun 2023
#
#   * Min = -5.709.176.430.000.000
#
#   * Max = 2.174.219.449.000.000
#
# **Kesimpulan:**
# Adanya nilai minimum negatif yang sangat besar menunjukkan kemungkinan akun keuangan seperti kerugian atau liabilitas Rentang nilai yang sangat lebar juga wajar karena data berasal dari laporan keuangan berbagai perusahaan dengan skala aset yang berbeda-beda
#
# ---
#
# 4. **Standar Deviasi (Std) – Variabilitas Data**
#
# * Tahun 2020
#
#   * Mean ≈ 1.19 triliun
#
#   * Std ≈ 153 triliun
#
# * Tahun 2021
#
#   * Mean ≈ 1.39 triliun
#
#   * Std ≈ 171 triliun
#
# * Tahun 2022
#
#   * Mean ≈ 1.49 triliun
#
#   * Std ≈ 188 triliun
#
# * Tahun 2023
#
#   * Mean ≈ 1.71 triliun
#
#   * Std ≈ 216 triliun
#
# **Kesimpulan:**
# Nilai standar deviasi yang jauh lebih besar daripada mean menunjukkan variabilitas data yang sangat tinggi Artinya perbedaan nilai laporan keuangan antar perusahaan sangat besar dari perusahaan kecil hingga perusahaan dengan aset dan nilai keuangan sangat besar. Hal ini wajar pada dataset laporan keuangan perusahaan publik (IDX)

# %% [markdown]
# ## **Data Type Check**

# %% [markdown]
# Kita akan mengecek tipe data dari setiap kolom apakah sudah sesuai atau tidak. Agar insight serta visualisasi yang akan kita buat menjadi akurat.
#
# Dan dapat dilihat dibawah ini, seluruh kolom sudah memiliki tipe data yang sesuai dengan jenis datanya, sehingga tidak perlu dilakukan konversi tipe data.

# %%
df.dtypes
# Out:
# symbol      object
# account     object
# type        object
# 2020       float64
# 2021       float64
# 2022       float64
# 2023       float64
# dtype: object

# %% [markdown]
# ## **Incosistent Values**

# %% [markdown]
# Pada tahap ini dilakukan pengecekan konsistensi nilai pada dataset untuk memastikan tidak terdapat perbedaan penulisan yang dapat menyebabkan kesalahan analisis. Ketidakkonsistenan data biasanya terjadi pada kolom bertipe kategorikal object seperti kode perusahaan, akun, dan tipe laporan.

# %% [markdown]
# 1. **Symbol (Kode Perusahaan)**
#
# Berdasarkan struktur data, kolom symbol berfungsi sebagai identitas utama perusahaan. Nilai pada kolom ini berbentuk kode unik perusahaan dan secara umum sudah konsisten karena menggunakan format kode saham yang seragam.

# %%
print(df['symbol'].unique())
# Out:
# ['AALI' 'ABBA' 'ABDA' 'ABMM' 'ACES' 'ACST' 'ADCP' 'ADES' 'ADHI' 'ADMF'
#  'ADMG' 'ADMR' 'ADRO' 'AGII' 'AGRO' 'AGRS' 'AISA' 'AKPI' 'AKRA' 'ALDO'
#  'ALII' 'ALMI' 'AMAG' 'AMAN' 'AMAR' 'AMFG' 'AMMN' 'AMOR' 'AMRT' 'ANDI'
#  'ANJT' 'ANTM' 'APEX' 'APIC' 'APLN' 'ARCI' 'ARGO' 'ARII' 'ARKA' 'ARKO'
#  'ARMY' 'ARNA' 'ARTI' 'ARTO' 'ASDM' 'ASGR' 'ASII' 'ASLC' 'ASMI' 'ASRI'
#  'ASRM' 'ASSA' 'ATIC' 'ATLA' 'AUTO' 'AVIA' 'BABP' 'BACA' 'BAJA' 'BALI'
#  'BANK' 'BAPA' 'BATA' 'BBCA' 'BBHI' 'BBKP' 'BBLD' 'BBMD' 'BBNI' 'BBRI'
#  'BBRM' 'BBSI' 'BBTN' 'BBYB' 'BCAP' 'BCIC' 'BCIP' 'BDKR' 'BDMN' 'BEBS'
#  'BEEF' 'BEKS' 'BELI' 'BEST' 'BFIN' 'BGTG' 'BHAT' 'BHIT' 'BINA' 'BIPI'
#  'BIPP' 'BIRD' 'BISI' 'BJBR' 'BJTM' 'BKDP' 'BKSL' 'BKSW' 'BLTA' 'BLTZ'
#  'BMAS' 'BMHS' 'BMRI' 'BMSR' 'BMTR' 'BNBA' 'BNBR' 'BNGA' 'BNII' 'BNLI'
#  'BOGA' 'BOLA' 'BOLT' 'BOSS' 'BPFI' 'BPII' 'BRAM' 'BREN' 'BRIS' 'BRMS'
#  'BRNA' 'BRPT' 'BSBK' 'BSDE' 'BSIM' 'BSSR' 'BSWD' 'BTEK' 'BTEL' 'BTPN'
#  'BTPS' 'BUAH' 'BUDI' 'BUKA' 'BUKK' 'BULL' 'BUMI' 'BUVA' 'BVIC' 'BWPT'
#  'BYAN' 'CAMP' 'CARE' 'CARS' 'CASA' 'CASS' 'CBUT' 'CEKA' 'CENT' 'CFIN'
#  'CGAS' 'CHIP' 'CITA' 'CITY' 'CLAY' 'CLEO' 'CLPI' 'CMNP' 'CMNT' 'CMPP'
#  'CMRY' 'CNKO' 'CNMA' 'CPIN' 'CPRO' 'CSAP' 'CSMI' 'CTBN' 'CTRA' 'CTTH'
#  'CUAN' 'CYBR' 'DART' 'DCII' 'DEAL' 'DEPO' 'DEWA' 'DFAM' 'DGIK' 'DILD'
#  'DIVA' 'DKFT' 'DLTA' 'DMAS' 'DMMX' 'DMND' 'DNAR' 'DNET' 'DOID' 'DOOH'
#  'DPUM' 'DRMA' 'DSNG' 'DSSA' 'DUTI' 'DVLA' 'DWGL' 'DYAN' 'ECII' 'EDGE'
#  'ELPI' 'ELSA' 'ELTY' 'EMDE' 'EMTK' 'ENAK' 'ENRG' 'ENVY' 'EPMT' 'ERAA'
#  'ERAL' 'ESSA' 'ETWA' 'EXCL' 'FAPA' 'FAST' 'FASW' 'FILM' 'FIRE' 'FISH'
#  'FMII' 'FPNI' 'FREN' 'FUJI' 'GAMA' 'GDST' 'GEMA' 'GEMS' 'GGRM' 'GGRP'
#  'GIAA' 'GJTL' 'GMFI' 'GMTD' 'GOLL' 'GOOD' 'GOTO' 'GPRA' 'GSMF' 'GTBO'
#  'GTSI' 'GWSA' 'GZCO' 'HATM' 'HDFA' 'HDTX' 'HEAL' 'HELI' 'HERO' 'HEXA'
#  'HILL' 'HITS' 'HMSP' 'HOKI' 'HOMI' 'HOTL' 'HRME' 'HRTA' 'HRUM' 'HUMI'
#  'IATA' 'IBOS' 'IBST' 'ICBP' 'IDPR' 'IFII' 'IFSH' 'IGAR' 'IIKP' 'IKAI'
#  'IKBI' 'IMAS' 'IMJS' 'IMPC' 'INAF' 'INAI' 'INCO' 'INDF' 'INDR' 'INDS'
#  'INDY' 'INET' 'INKP' 'INPC' 'INPP' 'INPS' 'INTA' 'INTP' 'IPCC' 'IPCM'
#  'IPOL' 'IPTV' 'IRRA' 'IRSX' 'ISAT' 'ISSP' 'ITMA' 'ITMG' 'JARR' 'JAWA'
#  'JAYA' 'JECC' 'JGLE' 'JIHD' 'JKON' 'JPFA' 'JRPT' 'JSKY' 'JSMR' 'JSPT'
#  'JTPE' 'KAEF' 'KARW' 'KBLI' 'KBLV' 'KEEN' 'KEJU' 'KIAS' 'KIJA' 'KINO'
#  'KIOS' 'KKGI' 'KLBF' 'KMTR' 'KOIN' 'KONI' 'KOTA' 'KPIG' 'KRAS' 'KREN'
#  'LAND' 'LAPD' 'LCGP' 'LIFE' 'LINK' 'LPCK' 'LPGI' 'LPKR' 'LPLI' 'LPPF'
#  'LPPS' 'LSIP' 'LTLS' 'MAGP' 'MAHA' 'MAIN' 'MAPA' 'MAPB' 'MAPI' 'MARK'
#  'MASA' 'MASB' 'MAYA' 'MBAP' 'MBMA' 'MBSS' 'MCAS' 'MCOL' 'MCOR' 'MDIA'
#  'MDKA' 'MDLN' 'MDRN' 'MEDC' 'MEGA' 'MERK' 'META' 'MFIN' 'MGRO' 'MICE'
#  'MIDI' 'MIKA' 'MINA' 'MIRA' 'MITI' 'MKNT' 'MKPI' 'MKTR' 'MLBI' 'MLIA'
#  'MLPL' 'MLPT' 'MMLP' 'MNCN' 'MOLI' 'MORA' 'MPMX' 'MPPA' 'MPRO' 'MRAT'
#  'MREI' 'MSIN' 'MSJA' 'MSKY' 'MSTI' 'MTDL' 'MTEL' 'MTFN' 'MTLA' 'MTMH'
#  'MTPS' 'MYOH' 'MYOR' 'MYTX' 'NASA' 'NATO' 'NCKL' 'NETV' 'NFCX' 'NICE'
#  'NICL' 'NIKL' 'NIRO' 'NISP' 'NOBU' 'NRCA' 'NSSS' 'OMED' 'OMRE' 'PADI'
#  'PALM' 'PANI' 'PANS' 'PBID' 'PBRX' 'PBSA' 'PCAR' 'PEGE' 'PEHA' 'PGAS'
#  'PGEO' 'PGLI' 'PGUN' 'PICO' 'PIPA' 'PJAA' 'PLIN' 'PMJS' 'PNBN' 'PNBS'
#  'PNIN' 'PNLF' 'POLA' 'POLI' 'POLL' 'POLU' 'POOL' 'PORT' 'POSA' 'POWR'
#  'PPRE' 'PPRO' 'PRAY' 'PRDA' 'PRIM' 'PSAB' 'PSGO' 'PSSI' 'PTBA' 'PTIS'
#  'PTMP' 'PTPP' 'PTRO' 'PTSN' 'PTSP' 'PWON' 'PYFA' 'PZZA' 'RAAM' 'RAJA'
#  'RALS' 'RDTX' 'RICY' 'RIGS' 'RISE' 'RMKE' 'RODA' 'ROTI' 'RSGK' 'RUIS'
#  'SAFE' 'SAGE' 'SAME' 'SAMF' 'SCCO' 'SCMA' 'SDMU' 'SDPC' 'SDRA' 'SFAN'
#  'SGER' 'SGRO' 'SHID' 'SHIP' 'SIDO' 'SILO' 'SIMP' 'SIPD' 'SKBM' 'SKLT'
#  'SKRN' 'SLIS' 'SMAR' 'SMBR' 'SMCB' 'SMDM' 'SMDR' 'SMGR' 'SMIL' 'SMMA'
#  'SMMT' 'SMRA' 'SMRU' 'SMSM' 'SOCI' 'SOHO' 'SONA' 'SPMA' 'SPTO' 'SQMI'
#  'SRAJ' 'SRIL' 'SRSN' 'SRTG' 'SSIA' 'SSMS' 'STAA' 'STAR' 'STRK' 'STTP'
#  'SULI' 'SUPR' 'SURE' 'SURI' 'TAMU' 'TAPG' 'TARA' 'TAXI' 'TBIG' 'TBLA'
#  'TCID' 'TCPI' 'TDPM' 'TEBE' 'TECH' 'TELE' 'TFAS' 'TFCO' 'TGKA' 'TGRA'
#  'TIFA' 'TINS' 'TIRT' 'TKIM' 'TLDN' 'TLKM' 'TMAS' 'TOBA' 'TOPS' 'TOTL'
#  'TOTO' 'TOWR' 'TPIA' 'TPMA' 'TRAM' 'TRGU' 'TRIL' 'TRIM' 'TRIN' 'TRIO'
#  'TRST' 'TSPC' 'TUGU' 'UCID' 'ULTJ' 'UNIC' 'UNSP' 'UNTD' 'UNTR' 'UNVR'
#  'URBN' 'VICI' 'VICO' 'VIVA' 'VKTR' 'VTNY' 'WEGE' 'WEHA' 'WIIM' 'WIKA'
#  'WINE' 'WINS' 'WIRG' 'WMPP' 'WMUU' 'WOMF' 'WOOD' 'WSBP' 'WSKT' 'WTON'
#  'YPAS' 'YULE' 'ZBRA' 'ZINC']

# %% [markdown]
# 2. **Account (Nama Akun Laporan Keuangan)**
#
# Kolom account berisi nama akun laporan keuangan seperti aset, liabilitas, pendapatan, dan lain-lain Dari hasil peninjauan terdapat kemungkinan variasi penulisan nama akun misalnya perbedaan spasi, kapitalisasi, atau istilah yang miri) karena data berasal dari berbagai entitas perusahaan

# %%
print(df['account'].unique())
# Out:
# ['Accounts Payable' 'Accounts Receivable' 'Accumulated Depreciation'
#  'Additional Paid In Capital' 'Allowance For Doubtful Accounts Receivable'
#  'Basic Average Shares' 'Basic EPS' 'Beginning Cash Position'
#  'Buildings And Improvements' 'Capital Expenditure'
#  'Capital Expenditure Reported' 'Capital Stock'
#  'Cash And Cash Equivalents'
#  'Cash Cash Equivalents And Short Term Investments' 'Cash Dividends Paid'
#  'Cash Equivalents' 'Cash Financial'
#  'Cash Flowsfromusedin Operating Activities Direct' 'Changes In Cash'
#  'Classesof Cash Payments'
#  'Classesof Cash Receiptsfrom Operating Activities' 'Common Stock'
#  'Common Stock Dividend Paid' 'Common Stock Equity'
#  'Construction In Progress' 'Cost Of Revenue' 'Current Assets'
#  'Current Debt' 'Current Debt And Capital Lease Obligation'
#  'Current Liabilities' 'Depreciation And Amortization In Income Statement'
#  'Depreciation Income Statement' 'Diluted Average Shares' 'Diluted EPS'
#  'Diluted NI Availto Com Stockholders' 'EBIT' 'EBITDA'
#  'Effect Of Exchange Rate Changes' 'End Cash Position'
#  'Financing Cash Flow' 'Finished Goods' 'Free Cash Flow'
#  'General And Administrative Expense' 'Goodwill'
#  'Goodwill And Other Intangible Assets' 'Gross Accounts Receivable'
#  'Gross PPE' 'Gross Profit' 'Impairment Of Capital Assets'
#  'Interest Expense' 'Interest Expense Non Operating' 'Interest Income'
#  'Interest Income Non Operating' 'Interest Paid Cff'
#  'Interest Received Direct' 'Inventory' 'Invested Capital'
#  'Investing Cash Flow' 'Investmentsin Joint Venturesat Cost'
#  'Issuance Of Debt' 'Land And Improvements' 'Long Term Debt'
#  'Long Term Debt And Capital Lease Obligation' 'Long Term Debt Issuance'
#  'Long Term Debt Payments' 'Long Term Equity Investment'
#  'Machinery Furniture Equipment' 'Minority Interest' 'Minority Interests'
#  'Net Debt' 'Net Income' 'Net Income Common Stockholders'
#  'Net Income Continuous Operations'
#  'Net Income From Continuing And Discontinued Operation'
#  'Net Income From Continuing Operation Net Minority Interest'
#  'Net Income Including Noncontrolling Interests' 'Net Interest Income'
#  'Net Issuance Payments Of Debt' 'Net Long Term Debt Issuance'
#  'Net Non Operating Interest Income Expense' 'Net Other Financing Charges'
#  'Net Other Investing Changes' 'Net PPE' 'Net PPE Purchase And Sale'
#  'Net Tangible Assets' 'Non Current Deferred Taxes Assets'
#  'Non Current Deferred Taxes Liabilities'
#  'Non Current Pension And Other Postretirement Benefit Plans'
#  'Normalized EBITDA' 'Normalized Income' 'Operating Expense'
#  'Operating Income' 'Operating Revenue' 'Ordinary Shares Number'
#  'Other Cash Paymentsfrom Operating Activities'
#  'Other Current Liabilities' 'Other Equity Interest' 'Other Inventories'
#  'Other Non Current Assets' 'Other Non Current Liabilities'
#  'Other Non Operating Income Expenses' 'Other Operating Expenses'
#  'Other Payable' 'Other Properties' 'Other Receivables'
#  'Other Special Charges' 'Otherunder Preferred Stock Dividend' 'Payables'
#  'Paymentsto Suppliersfor Goodsand Services'
#  'Pensionand Other Post Retirement Benefit Plans Current' 'Prepaid Assets'
#  'Pretax Income' 'Properties' 'Purchase Of PPE' 'Raw Materials'
#  'Receiptsfrom Customers' 'Reconciled Cost Of Revenue'
#  'Reconciled Depreciation' 'Repayment Of Debt' 'Research And Development'
#  'Retained Earnings' 'Selling And Marketing Expense'
#  'Selling General And Administration' 'Share Issued'
#  'Special Income Charges' 'Stockholders Equity' 'Tangible Book Value'
#  'Tax Effect Of Unusual Items' 'Tax Provision' 'Tax Rate For Calcs'
#  'Taxes Refund Paid Direct' 'Total Assets' 'Total Capitalization'
#  'Total Debt' 'Total Equity Gross Minority Interest' 'Total Expenses'
#  'Total Liabilities Net Minority Interest' 'Total Non Current Assets'
#  'Total Non Current Liabilities Net Minority Interest'
#  'Total Other Finance Cost' 'Total Revenue' 'Total Tax Payable'
#  'Total Unusual Items' 'Total Unusual Items Excluding Goodwill'
#  'Treasury Shares Number' 'Work In Process' 'Working Capital' 'Write Off'
#  'Amortization' 'Available For Sale Securities'
#  'Capital Lease Obligations' 'Common Stock Issuance'
#  'Current Capital Lease Obligation' 'Current Deferred Taxes Liabilities'
#  'Dividends Payable' 'Dividends Received Cfi' 'Interest Paid Direct'
#  'Inventories Adjustments Allowances' 'Investmentin Financial Assets'
#  'Investmentsin Associatesat Cost' 'Issuance Of Capital Stock'
#  'Long Term Capital Lease Obligation' 'Net Business Purchase And Sale'
#  'Net Common Stock Issuance' 'Net Intangibles Purchase And Sale'
#  'Net Investment Properties Purchase And Sale'
#  'Net Short Term Debt Issuance' 'Non Current Deferred Revenue'
#  'Other Cash Adjustment Outside Changein Cash'
#  'Other Cash Receiptsfrom Operating Activities' 'Other Intangible Assets'
#  'Other Short Term Investments' 'Paymentson Behalfof Employees'
#  'Purchase Of Business' 'Purchase Of Intangibles' 'Rent And Landing Fees'
#  'Rent Expense Supplemental' 'Sale Of Investment Properties' 'Sale Of PPE'
#  'Short Term Debt Issuance' 'Short Term Debt Payments'
#  'Tradeand Other Payables Non Current' 'Investment Properties'
#  'Investments And Advances'
#  'Investments In Other Ventures Under Equity Method'
#  'Net Investment Purchase And Sale' 'Other Income Expense'
#  'Purchase Of Investment' 'Restructuring And Mergern Acquisition'
#  'Sale Of Investment' 'Trading Securities' 'Assets Held For Sale Current'
#  'Long Term Provisions' 'Non Current Deferred Assets'
#  'Non Current Prepaid Assets' 'Other Current Assets' 'Restricted Cash'
#  'Sale Of Business' 'Total Operating Income As Reported'
#  'Common Stock Payments' 'Investmentsin Subsidiariesat Cost'
#  'Purchase Of Investment Properties' 'Repurchase Of Capital Stock'
#  'Treasury Stock' 'Current Deferred Assets'
#  'Other Cash Adjustment Inside Changein Cash'
#  'Held To Maturity Securities' 'Sale Of Intangibles' 'Current Provisions'
#  'Financial Assets Designatedas Fair Value Through Profitor Loss Total'
#  'Fixed Assets Revaluation Reserve' 'Interest Received Cfi'
#  'Other Investments' 'Taxes Receivable' 'Derivative Product Liabilities'
#  'Financial Assets' 'Gain On Sale Of Security' 'Insurance And Claims'
#  'Operating Cash Flow' 'Receivables' 'Net Income Extraordinary'
#  'Net Income Discontinuous Operations' 'Non Current Accrued Expenses'
#  'Hedging Assets Current' 'Net Preferred Stock Issuance'
#  'Preferred Stock Issuance' 'Defined Pension Benefit'
#  'Receivables Adjustments Allowances' 'Change In Other Current Assets'
#  'Change In Other Current Liabilities' 'Change In Payable'
#  'Change In Receivables' 'Change In Working Capital' 'Interest Paid Cfo'
#  'Interest Received Cfo' 'Taxes Refund Paid' 'Preferred Stock Dividends'
#  'Liabilities Heldfor Sale Non Current' 'Dividends Received Direct'
#  'Dividends Paid Direct' 'Preferred Shares Number'
#  'Change In Accrued Expense' 'Net Foreign Currency Exchange Gain Loss'
#  'Cash Flow From Continuing Financing Activities'
#  'Cash Flow From Continuing Investing Activities'
#  'Current Accrued Expenses' 'Current Deferred Liabilities'
#  'Current Deferred Revenue'
#  'Depreciation Amortization Depletion Income Statement'
#  'Earnings From Equity Interest' 'Employee Benefits'
#  'Gains Losses Not Affecting Retained Earnings' 'Income Tax Payable'
#  'Interest Payable' 'Leases' 'Line Of Credit'
#  'Non Current Accounts Receivable' 'Non Current Deferred Liabilities'
#  'Other Current Borrowings' 'Other Equity Adjustments' 'Other Gand A'
#  'Payables And Accrued Expenses' 'Provision For Doubtful Accounts'
#  'Salaries And Wages']

# %% [markdown]
# 3.  **Type (Jenis Laporan Keuangan)**
#
# Kolom type menunjukkan jenis laporan keuangan, seperti:
#
# * BS (Balance Sheet)
#
# * IS (Income Statement)
#
# * CF (Cash Flow)
#
# Nilai pada kolom ini relatif terbatas dan konsisten karena menggunakan kode singkatan standar laporan keuangan.

# %%
print(df['type'].unique())
# Out:
# ['BS' 'IS' 'CF']

# %% [markdown]
# 4. **Kolom Tahun (2020, 2021, 2022, 2023)**
#
# Kolom tahun berisi nilai numerik bertipe float yang merepresentasikan nilai keuangan perusahaan pada masing-masing tahun Karena berbentuk angka inkonsistensi format tidak ditemukan namun terdapat indikasi nilai kosong missing values pada beberapa entri yang terlihat dari jumlah data yang tidak selalu penu

# %%
print(df['2020'].unique())
# Out:
# [ 7.70264000e+11  7.65849000e+11 -1.09209480e+13 ...  1.54245597e+11
#   3.75770262e+08  5.36558887e+10]

# %%
print(df['2021'].unique())
# Out:
# [ 1.02671700e+12  4.58135000e+11 -1.21338130e+13 ...  3.41880000e+09
#   3.75770262e+08  4.59909106e+11]

# %%
print(df['2022'].unique())
# Out:
# [ 1.22442300e+12  8.48770000e+11 -1.33037490e+13 ...  3.41880000e+09
#   3.87452172e+09 -3.02363298e+10]

# %%
print(df['2023'].unique())
# Out:
# [ 8.42064000e+11  6.74487000e+11 -1.44368470e+13 ...  3.41880000e+09
#   7.06729200e+10  1.28536743e+11]

# %% [markdown]
# $# **Missing Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat seberapa banyak data yang hilang pada seluruh kolom. Dan terlihat bahwa kolom:
#
# **2020**
#
# Memiliki missing values sekitar 5,8%, yang dimana hal ini perlu ditangani atau dihapus.
#
# **2021**
#
# Memiliki missing values sekitar 5,3% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.
#
# **2022**
#
# Memiliki missing values sekitar 6,2% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.
#
# **2023**
#
# Memiliki missing values sekitar 23%, yang dimana ini cukup besar dibandingkan pada tahun-tahun sebelumnya. Sehingga perlu ditangani atau dihapus.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#          Null Ratio in %
# symbol          0.000000
# account         0.000000
# type            0.000000
# 2020            5.888417
# 2021            5.343836
# 2022            6.285087
# 2023           21.751846

# %% [markdown]
# ## **Duplicated Values**

# %% [markdown]
# Pada tahap ini, kita akan mengecek duplikasi pada dataset. Hal ini dilakukan agar dataset memiliki insight dan hasil yang bersih.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [symbol, account, type, 2020, 2021, 2022, 2023]
# Index: []

# %% [markdown]
# Terlihat pada dataset ini tidak ada duplikasi. Maka hal ini tidak perlu ditangani, namun jika ingin menangani anda dapat mengetikkan
#
# df = df.drop_duplicates()

# %% [markdown]
# ## **Outliers Values**

# %% [markdown]
# Pada tahap ini, dilakukan pengecekan nilai ekstrem (outliers) pada kolom numerik yaitu 2020, 2021, 2022, dan 2023. Hal ini bertujuan agar mendapatkan insight yang lebih akurat serta memahami sebaran nilai keuangan pada dataset
#
# Dan terlihat pada kolom:
#
# **2020**
#
# Dengan persentase outliers 20,8% yang cukup tinggi karena terdapat perbedaan nilai keuangan antar perusahaan yang sangat besar.
#
# **2021**
#
# Dengan persentase outliers 20,1% yang masih tinggi dan menunjukkan variasi nilai yang semakin melebar.
#
# **2022**
#
#
# Dengan persentase outliers 19,5% yang signifikan akibat adanya nilai maksimum yang jauh di atas sebagian besar data.
#
# **2023**
#
# Dengan persentase outliers 16,4% yang tetap tinggi dan rentang data yang sangat luas.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

#Dataframe dari list hasil

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

#Tampilkan dataframe

display(results_df)
# Out:
# Kolom  Persentase Outliers
# 2020             20.889033
# 2021             20.119225
# 2022             19.589211
# 2023             16.413612

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df[['2020', '2021', '2022', '2023']])
plt.yscale('log')
plt.title('Boxplot Nilai Keuangan Tahun 2020-2023 ')
plt.xlabel('Tahun')
plt.ylabel('Nilai ')
plt.show()

# %% [markdown]
# ## **Eksplorasi Data (EDA)**

# %% [markdown]
# ### **Comparison(Perbandingan)**

# %% [markdown]
# Aktivitas: Membandingkan total nilai laporan keuangan pada setiap perusahaan (symblo) berdasarkan akumulasi tahun 2020–2023.
#
# Tujuan: Mengidentifikasi perusahaan mana yang memberikan kontribusi nilai keuangan terbesar serta membandingkan kinerja keuangan antar perusahaan secara langsung dalam periode 2020–2023.
#
# Visualisasi: Bar Chart (Grafik Batang).

# %%
laporan_tahunan = df.groupby('symbol')[['2020', '2021', '2022', '2023']].sum()

laporan_tahunan['Total'] = laporan_tahunan.sum(axis=1)

top10 = laporan_tahunan.sort_values('Total', ascending=False).head(10)

plt.figure(figsize=(12,7))
top10['Total'].plot(kind='bar', color='teal')
plt.title('Top 10 Perusahaan Berdasarkan Total Keuangan (2020-2023)')
plt.xlabel('Perusahaan (Symbol)')
plt.ylabel('Total Keuangan')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Composition(Komposisi)**

# %% [markdown]
# Aktivitas: Melihat proporsi atau persentase total nilai laporan keuangan berdasarkan perusahaan (symblo) pada periode 2020–2023.
#
# Tujuan: Mengetahui perusahaan mana yang paling mendominasi total nilai laporan keuangan secara keseluruhan, serta melihat kontribusi masing-masing perusahaan terhadap total nilai keuangan dalam dataset.
#
# Visualisasi: Pie Chart (Grafik Lingkaran)

# %%
total_2023 = df.groupby('symbol')[['2020', '2021', '2022', '2023']].sum().sum(axis=1).sort_values(ascending=False)
top3_2023 = total_2023.head(3)

plt.figure(figsize=(8,8))
plt.pie(
    top3_2023,
    labels=top3_2023.index,
    autopct='%1.1f%%',
    startangle=140
)

plt.title('Proporsi 3 Perusahaan Terbesar Tahun 2020-2023')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### **Distribution(Distribusi)**

# %% [markdown]
# ktivitas: Menganalisis penyebaran nilai laporan keuangan pada kolom tahun 2020–2023.
#
# Tujuan: Melihat apakah mayoritas nilai laporan keuangan berada pada rentang rendah atau tinggi, serta mendeteksi adanya kecondongan (skewness) pada distribusi data keuangan perusahaan.
#
# Visualisasi: Histogram.

# %%
df_melted_years = df.melt(
    value_vars=['2020', '2021', '2022', '2023'],
    var_name='Tahun',
    value_name='laporan_keuangan_value'
)
plt.figure(figsize=(10, 6))
sns.histplot(df_melted_years['laporan_keuangan_value'], bins=20, kde=True)
plt.title('Distribusi laporan Keuangan 2020-2023')
plt.xlabel('laporan keuangan 2020-2023')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ### **Relationship(Hubungan)**

# %% [markdown]
# Aktivitas: Menganalisis korelasi antara nilai laporan keuangan pada tahun 2020, 2021, 2022, dan 2023.
#
# Tujuan: Mengetahui apakah terdapat hubungan antar nilai laporan keuangan setiap tahun, serta melihat konsistensi kinerja keuangan perusahaan dari tahun ke tahun. Analisis ini membantu memahami apakah kenaikan atau penurunan nilai keuangan pada satu tahun berkaitan dengan tahun lainnya.
#
# Visualisasi: Heatmap (Korelasi antar laporan keuangan tahunan)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    data=df[['2020', '2021', '2022', '2023']].corr(),
    annot=True,
    cmap='viridis',
    fmt='.2f'
)

plt.title('Korelasi Antar Laporan Keuangan Tahun 2020-2023')
plt.show()

# %% [markdown]
# # **chekpoint 3**

# %% [markdown]
# ### **Tipe Data**

# %% [markdown]
# **Tipe data berfungsi** untuk Kita mengecek tipe data dari setiap kolom apakah sudah sesuai atau tidak Agar insight serta visualisasi yang akan kita buat menjadi akurat

# %%
df.dtypes
# Out:
# symbol      object
# account     object
# type        object
# 2020       float64
# 2021       float64
# 2022       float64
# 2023       float64
# dtype: object

# %% [markdown]
# setelah di lakukan pemeriksaan tipe data, setiap kolom memiliki tipe yang sesuai dengan karakteristik datanya seprti symbol,account dan type memiliki tipe data **object** lalu 2020,2021,2022,dan 2023 meiliki tipe data **float64**
# **jadi tipe datanya sudah sesuai hingga tidak perlu konversi tambahan**

# %% [markdown]
# ### **Mising Values**

# %% [markdown]
# Pada tahap ini dilakukan penanganan terhadap data yang kosong atau tidak terisi agar tidak mengganggu proses analisis. Bagian yang kosong akan dicek terlebih dahulu untuk melihat jumlahnya. Jika jumlahnya mencapai atau >=70%, maka kolom tersebut sebaiknya dihapus karena dianggap terlalu banyak kekosongan dan dapat menurunkan kualitas analisis. Namun jika jumlahnya <=70%, maka nilainya dapat diisi menggunakan metode tertentu agar data tetap bisa digunakan. Langkah ini penting supaya hasil analisis tetap akurat dan tidak menghasilkan kesimpulan yang keliru akibat data yang tidak lengkap.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#          Null Ratio in %
# symbol          0.000000
# account         0.000000
# type            0.000000
# 2020            5.888417
# 2021            5.343836
# 2022            6.285087
# 2023           21.751846

# %% [markdown]
#  Dan terlihat bahwa:
# 1. terdapat kolom yang memiliki missing values pada kolom 2020 sebanyak (5,8%)
# 2. terdapat kolom yang memiliki missing values pada kolom 2021 sebanyak (5,3%)
# 3. terdapat kolom yang memiliki missing values pada kolom 2022 sebanyak (6,2%)
# 4. terdapat kolom yang memiliki missing values pada kolom 2023 sebanyak (21,7%).
#
# ditemukan indikasi kehilangan data pada kolom 2020,2021,2022, dan 2023. Dengan demikian,diperlukan penanganan seperti imputasi data dan tidak perlu melakukan penghapusan data karena miging values belum lebih dari 70%.

# %%
df['2020'] = df['2020'].fillna(df['2020'].median())
df['2021'] = df['2021'].fillna(df['2021'].mean())
df['2022'] = df['2022'].fillna(df['2022'].mean())
df['2023'] = df['2023'].fillna(df['2023'].mean())

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#          Null Ratio in %
# symbol               0.0
# account              0.0
# type                 0.0
# 2020                 0.0
# 2021                 0.0
# 2022                 0.0
# 2023                 0.0

# %% [markdown]
# setelah di lakukan imputasi pada kolom 2020,2021,2022,dan 2023 maka data yang sebelumnya terdapat mising values sekaring sudah tidak ada lagi mising values yang melebihi Non/noll dan data dapat di analisi lebih lanjut

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Pada tahap ini, kita akan mengecek duplikasi pada dataset. Hal ini dilakukan agar dataset memiliki insight dan hasil yang bersih.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [symbol, account, type, 2020, 2021, 2022, 2023]
# Index: []

# %% [markdown]
# Terlihat pada dataset ini tidak ada duplikasi. Maka hal ini tidak perlu ditangani, namun jika ingin menangani anda dapat mengetikkan
#
# df = df.drop_duplicates()

# %% [markdown]
# ### **Incosistent Values**

# %% [markdown]
# Pada tahap ini dilakukan penanganan nilai yang tidak konsisten agar isi data menjadi lebih seragam dan terkontrol. Biasanya dicek terlebih dahulu bagian mana yang penulisannya berbeda padahal memiliki maksud yang sama, kemudian diperbaiki atau disesuaikan ke format yang sudah ditentukan. Dengan begitu, data tidak terbaca sebagai kategori yang berbeda dan proses analisis dapat berjalan lebih akurat tanpa terganggu oleh perbedaan penulisan yang sebenarnya tidak diperlukan.

# %%
print(df['symbol'].unique())
print(df['account'].unique())
print(df['type'].unique())
# Out:
# ['AALI' 'ABBA' 'ABDA' 'ABMM' 'ACES' 'ACST' 'ADCP' 'ADES' 'ADHI' 'ADMF'
#  'ADMG' 'ADMR' 'ADRO' 'AGII' 'AGRO' 'AGRS' 'AISA' 'AKPI' 'AKRA' 'ALDO'
#  'ALII' 'ALMI' 'AMAG' 'AMAN' 'AMAR' 'AMFG' 'AMMN' 'AMOR' 'AMRT' 'ANDI'
#  'ANJT' 'ANTM' 'APEX' 'APIC' 'APLN' 'ARCI' 'ARGO' 'ARII' 'ARKA' 'ARKO'
#  'ARMY' 'ARNA' 'ARTI' 'ARTO' 'ASDM' 'ASGR' 'ASII' 'ASLC' 'ASMI' 'ASRI'
#  'ASRM' 'ASSA' 'ATIC' 'ATLA' 'AUTO' 'AVIA' 'BABP' 'BACA' 'BAJA' 'BALI'
#  'BANK' 'BAPA' 'BATA' 'BBCA' 'BBHI' 'BBKP' 'BBLD' 'BBMD' 'BBNI' 'BBRI'
#  'BBRM' 'BBSI' 'BBTN' 'BBYB' 'BCAP' 'BCIC' 'BCIP' 'BDKR' 'BDMN' 'BEBS'
#  'BEEF' 'BEKS' 'BELI' 'BEST' 'BFIN' 'BGTG' 'BHAT' 'BHIT' 'BINA' 'BIPI'
#  'BIPP' 'BIRD' 'BISI' 'BJBR' 'BJTM' 'BKDP' 'BKSL' 'BKSW' 'BLTA' 'BLTZ'
#  'BMAS' 'BMHS' 'BMRI' 'BMSR' 'BMTR' 'BNBA' 'BNBR' 'BNGA' 'BNII' 'BNLI'
#  'BOGA' 'BOLA' 'BOLT' 'BOSS' 'BPFI' 'BPII' 'BRAM' 'BREN' 'BRIS' 'BRMS'
#  'BRNA' 'BRPT' 'BSBK' 'BSDE' 'BSIM' 'BSSR' 'BSWD' 'BTEK' 'BTEL' 'BTPN'
#  'BTPS' 'BUAH' 'BUDI' 'BUKA' 'BUKK' 'BULL' 'BUMI' 'BUVA' 'BVIC' 'BWPT'
#  'BYAN' 'CAMP' 'CARE' 'CARS' 'CASA' 'CASS' 'CBUT' 'CEKA' 'CENT' 'CFIN'
#  'CGAS' 'CHIP' 'CITA' 'CITY' 'CLAY' 'CLEO' 'CLPI' 'CMNP' 'CMNT' 'CMPP'
#  'CMRY' 'CNKO' 'CNMA' 'CPIN' 'CPRO' 'CSAP' 'CSMI' 'CTBN' 'CTRA' 'CTTH'
#  'CUAN' 'CYBR' 'DART' 'DCII' 'DEAL' 'DEPO' 'DEWA' 'DFAM' 'DGIK' 'DILD'
#  'DIVA' 'DKFT' 'DLTA' 'DMAS' 'DMMX' 'DMND' 'DNAR' 'DNET' 'DOID' 'DOOH'
#  'DPUM' 'DRMA' 'DSNG' 'DSSA' 'DUTI' 'DVLA' 'DWGL' 'DYAN' 'ECII' 'EDGE'
#  'ELPI' 'ELSA' 'ELTY' 'EMDE' 'EMTK' 'ENAK' 'ENRG' 'ENVY' 'EPMT' 'ERAA'
#  'ERAL' 'ESSA' 'ETWA' 'EXCL' 'FAPA' 'FAST' 'FASW' 'FILM' 'FIRE' 'FISH'
#  'FMII' 'FPNI' 'FREN' 'FUJI' 'GAMA' 'GDST' 'GEMA' 'GEMS' 'GGRM' 'GGRP'
#  'GIAA' 'GJTL' 'GMFI' 'GMTD' 'GOLL' 'GOOD' 'GOTO' 'GPRA' 'GSMF' 'GTBO'
#  'GTSI' 'GWSA' 'GZCO' 'HATM' 'HDFA' 'HDTX' 'HEAL' 'HELI' 'HERO' 'HEXA'
#  'HILL' 'HITS' 'HMSP' 'HOKI' 'HOMI' 'HOTL' 'HRME' 'HRTA' 'HRUM' 'HUMI'
#  'IATA' 'IBOS' 'IBST' 'ICBP' 'IDPR' 'IFII' 'IFSH' 'IGAR' 'IIKP' 'IKAI'
#  'IKBI' 'IMAS' 'IMJS' 'IMPC' 'INAF' 'INAI' 'INCO' 'INDF' 'INDR' 'INDS'
#  'INDY' 'INET' 'INKP' 'INPC' 'INPP' 'INPS' 'INTA' 'INTP' 'IPCC' 'IPCM'
#  'IPOL' 'IPTV' 'IRRA' 'IRSX' 'ISAT' 'ISSP' 'ITMA' 'ITMG' 'JARR' 'JAWA'
#  'JAYA' 'JECC' 'JGLE' 'JIHD' 'JKON' 'JPFA' 'JRPT' 'JSKY' 'JSMR' 'JSPT'
#  'JTPE' 'KAEF' 'KARW' 'KBLI' 'KBLV' 'KEEN' 'KEJU' 'KIAS' 'KIJA' 'KINO'
#  'KIOS' 'KKGI' 'KLBF' 'KMTR' 'KOIN' 'KONI' 'KOTA' 'KPIG' 'KRAS' 'KREN'
#  'LAND' 'LAPD' 'LCGP' 'LIFE' 'LINK' 'LPCK' 'LPGI' 'LPKR' 'LPLI' 'LPPF'
#  'LPPS' 'LSIP' 'LTLS' 'MAGP' 'MAHA' 'MAIN' 'MAPA' 'MAPB' 'MAPI' 'MARK'
#  'MASA' 'MASB' 'MAYA' 'MBAP' 'MBMA' 'MBSS' 'MCAS' 'MCOL' 'MCOR' 'MDIA'
#  'MDKA' 'MDLN' 'MDRN' 'MEDC' 'MEGA' 'MERK' 'META' 'MFIN' 'MGRO' 'MICE'
#  'MIDI' 'MIKA' 'MINA' 'MIRA' 'MITI' 'MKNT' 'MKPI' 'MKTR' 'MLBI' 'MLIA'
#  'MLPL' 'MLPT' 'MMLP' 'MNCN' 'MOLI' 'MORA' 'MPMX' 'MPPA' 'MPRO' 'MRAT'
#  'MREI' 'MSIN' 'MSJA' 'MSKY' 'MSTI' 'MTDL' 'MTEL' 'MTFN' 'MTLA' 'MTMH'
#  'MTPS' 'MYOH' 'MYOR' 'MYTX' 'NASA' 'NATO' 'NCKL' 'NETV' 'NFCX' 'NICE'
#  'NICL' 'NIKL' 'NIRO' 'NISP' 'NOBU' 'NRCA' 'NSSS' 'OMED' 'OMRE' 'PADI'
#  'PALM' 'PANI' 'PANS' 'PBID' 'PBRX' 'PBSA' 'PCAR' 'PEGE' 'PEHA' 'PGAS'
#  'PGEO' 'PGLI' 'PGUN' 'PICO' 'PIPA' 'PJAA' 'PLIN' 'PMJS' 'PNBN' 'PNBS'
#  'PNIN' 'PNLF' 'POLA' 'POLI' 'POLL' 'POLU' 'POOL' 'PORT' 'POSA' 'POWR'
#  'PPRE' 'PPRO' 'PRAY' 'PRDA' 'PRIM' 'PSAB' 'PSGO' 'PSSI' 'PTBA' 'PTIS'
#  'PTMP' 'PTPP' 'PTRO' 'PTSN' 'PTSP' 'PWON' 'PYFA' 'PZZA' 'RAAM' 'RAJA'
#  'RALS' 'RDTX' 'RICY' 'RIGS' 'RISE' 'RMKE' 'RODA' 'ROTI' 'RSGK' 'RUIS'
#  'SAFE' 'SAGE' 'SAME' 'SAMF' 'SCCO' 'SCMA' 'SDMU' 'SDPC' 'SDRA' 'SFAN'
#  'SGER' 'SGRO' 'SHID' 'SHIP' 'SIDO' 'SILO' 'SIMP' 'SIPD' 'SKBM' 'SKLT'
#  'SKRN' 'SLIS' 'SMAR' 'SMBR' 'SMCB' 'SMDM' 'SMDR' 'SMGR' 'SMIL' 'SMMA'
#  'SMMT' 'SMRA' 'SMRU' 'SMSM' 'SOCI' 'SOHO' 'SONA' 'SPMA' 'SPTO' 'SQMI'
#  'SRAJ' 'SRIL' 'SRSN' 'SRTG' 'SSIA' 'SSMS' 'STAA' 'STAR' 'STRK' 'STTP'
#  'SULI' 'SUPR' 'SURE' 'SURI' 'TAMU' 'TAPG' 'TARA' 'TAXI' 'TBIG' 'TBLA'
#  'TCID' 'TCPI' 'TDPM' 'TEBE' 'TECH' 'TELE' 'TFAS' 'TFCO' 'TGKA' 'TGRA'
#  'TIFA' 'TINS' 'TIRT' 'TKIM' 'TLDN' 'TLKM' 'TMAS' 'TOBA' 'TOPS' 'TOTL'
#  'TOTO' 'TOWR' 'TPIA' 'TPMA' 'TRAM' 'TRGU' 'TRIL' 'TRIM' 'TRIN' 'TRIO'
#  'TRST' 'TSPC' 'TUGU' 'UCID' 'ULTJ' 'UNIC' 'UNSP' 'UNTD' 'UNTR' 'UNVR'
#  'URBN' 'VICI' 'VICO' 'VIVA' 'VKTR' 'VTNY' 'WEGE' 'WEHA' 'WIIM' 'WIKA'
#  'WINE' 'WINS' 'WIRG' 'WMPP' 'WMUU' 'WOMF' 'WOOD' 'WSBP' 'WSKT' 'WTON'
#  'YPAS' 'YULE' 'ZBRA' 'ZINC']
# ['Accounts Payable' 'Accounts Receivable' 'Accumulated Depreciation'
#  'Additional Paid In Capital' 'Allowance For Doubtful Accounts Receivable'
#  'Basic Average Shares' 'Basic EPS' 'Beginning Cash Position'
#  'Buildings And Improvements' 'Capital Expenditure'
#  'Capital Expenditure Reported' 'Capital Stock'
#  'Cash And Cash Equivalents'
#  'Cash Cash Equivalents And Short Term Investments' 'Cash Dividends Paid'
#  'Cash Equivalents' 'Cash Financial'
#  'Cash Flowsfromusedin Operating Activities Direct' 'Changes In Cash'
#  'Classesof Cash Payments'
#  'Classesof Cash Receiptsfrom Operating Activities' 'Common Stock'
#  'Common Stock Dividend Paid' 'Common Stock Equity'
#  'Construction In Progress' 'Cost Of Revenue' 'Current Assets'
#  'Current Debt' 'Current Debt And Capital Lease Obligation'
#  'Current Liabilities' 'Depreciation And Amortization In Income Statement'
#  'Depreciation Income Statement' 'Diluted Average Shares' 'Diluted EPS'
#  'Diluted NI Availto Com Stockholders' 'EBIT' 'EBITDA'
#  'Effect Of Exchange Rate Changes' 'End Cash Position'
#  'Financing Cash Flow' 'Finished Goods' 'Free Cash Flow'
#  'General And Administrative Expense' 'Goodwill'
#  'Goodwill And Other Intangible Assets' 'Gross Accounts Receivable'
#  'Gross PPE' 'Gross Profit' 'Impairment Of Capital Assets'
#  'Interest Expense' 'Interest Expense Non Operating' 'Interest Income'
#  'Interest Income Non Operating' 'Interest Paid Cff'
#  'Interest Received Direct' 'Inventory' 'Invested Capital'
#  'Investing Cash Flow' 'Investmentsin Joint Venturesat Cost'
#  'Issuance Of Debt' 'Land And Improvements' 'Long Term Debt'
#  'Long Term Debt And Capital Lease Obligation' 'Long Term Debt Issuance'
#  'Long Term Debt Payments' 'Long Term Equity Investment'
#  'Machinery Furniture Equipment' 'Minority Interest' 'Minority Interests'
#  'Net Debt' 'Net Income' 'Net Income Common Stockholders'
#  'Net Income Continuous Operations'
#  'Net Income From Continuing And Discontinued Operation'
#  'Net Income From Continuing Operation Net Minority Interest'
#  'Net Income Including Noncontrolling Interests' 'Net Interest Income'
#  'Net Issuance Payments Of Debt' 'Net Long Term Debt Issuance'
#  'Net Non Operating Interest Income Expense' 'Net Other Financing Charges'
#  'Net Other Investing Changes' 'Net PPE' 'Net PPE Purchase And Sale'
#  'Net Tangible Assets' 'Non Current Deferred Taxes Assets'
#  'Non Current Deferred Taxes Liabilities'
#  'Non Current Pension And Other Postretirement Benefit Plans'
#  'Normalized EBITDA' 'Normalized Income' 'Operating Expense'
#  'Operating Income' 'Operating Revenue' 'Ordinary Shares Number'
#  'Other Cash Paymentsfrom Operating Activities'
#  'Other Current Liabilities' 'Other Equity Interest' 'Other Inventories'
#  'Other Non Current Assets' 'Other Non Current Liabilities'
#  'Other Non Operating Income Expenses' 'Other Operating Expenses'
#  'Other Payable' 'Other Properties' 'Other Receivables'
#  'Other Special Charges' 'Otherunder Preferred Stock Dividend' 'Payables'
#  'Paymentsto Suppliersfor Goodsand Services'
#  'Pensionand Other Post Retirement Benefit Plans Current' 'Prepaid Assets'
#  'Pretax Income' 'Properties' 'Purchase Of PPE' 'Raw Materials'
#  'Receiptsfrom Customers' 'Reconciled Cost Of Revenue'
#  'Reconciled Depreciation' 'Repayment Of Debt' 'Research And Development'
#  'Retained Earnings' 'Selling And Marketing Expense'
#  'Selling General And Administration' 'Share Issued'
#  'Special Income Charges' 'Stockholders Equity' 'Tangible Book Value'
#  'Tax Effect Of Unusual Items' 'Tax Provision' 'Tax Rate For Calcs'
#  'Taxes Refund Paid Direct' 'Total Assets' 'Total Capitalization'
#  'Total Debt' 'Total Equity Gross Minority Interest' 'Total Expenses'
#  'Total Liabilities Net Minority Interest' 'Total Non Current Assets'
#  'Total Non Current Liabilities Net Minority Interest'
#  'Total Other Finance Cost' 'Total Revenue' 'Total Tax Payable'
#  'Total Unusual Items' 'Total Unusual Items Excluding Goodwill'
#  'Treasury Shares Number' 'Work In Process' 'Working Capital' 'Write Off'
#  'Amortization' 'Available For Sale Securities'
#  'Capital Lease Obligations' 'Common Stock Issuance'
#  'Current Capital Lease Obligation' 'Current Deferred Taxes Liabilities'
#  'Dividends Payable' 'Dividends Received Cfi' 'Interest Paid Direct'
#  'Inventories Adjustments Allowances' 'Investmentin Financial Assets'
#  'Investmentsin Associatesat Cost' 'Issuance Of Capital Stock'
#  'Long Term Capital Lease Obligation' 'Net Business Purchase And Sale'
#  'Net Common Stock Issuance' 'Net Intangibles Purchase And Sale'
#  'Net Investment Properties Purchase And Sale'
#  'Net Short Term Debt Issuance' 'Non Current Deferred Revenue'
#  'Other Cash Adjustment Outside Changein Cash'
#  'Other Cash Receiptsfrom Operating Activities' 'Other Intangible Assets'
#  'Other Short Term Investments' 'Paymentson Behalfof Employees'
#  'Purchase Of Business' 'Purchase Of Intangibles' 'Rent And Landing Fees'
#  'Rent Expense Supplemental' 'Sale Of Investment Properties' 'Sale Of PPE'
#  'Short Term Debt Issuance' 'Short Term Debt Payments'
#  'Tradeand Other Payables Non Current' 'Investment Properties'
#  'Investments And Advances'
#  'Investments In Other Ventures Under Equity Method'
#  'Net Investment Purchase And Sale' 'Other Income Expense'
#  'Purchase Of Investment' 'Restructuring And Mergern Acquisition'
#  'Sale Of Investment' 'Trading Securities' 'Assets Held For Sale Current'
#  'Long Term Provisions' 'Non Current Deferred Assets'
#  'Non Current Prepaid Assets' 'Other Current Assets' 'Restricted Cash'
#  'Sale Of Business' 'Total Operating Income As Reported'
#  'Common Stock Payments' 'Investmentsin Subsidiariesat Cost'
#  'Purchase Of Investment Properties' 'Repurchase Of Capital Stock'
#  'Treasury Stock' 'Current Deferred Assets'
#  'Other Cash Adjustment Inside Changein Cash'
#  'Held To Maturity Securities' 'Sale Of Intangibles' 'Current Provisions'
#  'Financial Assets Designatedas Fair Value Through Profitor Loss Total'
#  'Fixed Assets Revaluation Reserve' 'Interest Received Cfi'
#  'Other Investments' 'Taxes Receivable' 'Derivative Product Liabilities'
#  'Financial Assets' 'Gain On Sale Of Security' 'Insurance And Claims'
#  'Operating Cash Flow' 'Receivables' 'Net Income Extraordinary'
#  'Net Income Discontinuous Operations' 'Non Current Accrued Expenses'
#  'Hedging Assets Current' 'Net Preferred Stock Issuance'
#  'Preferred Stock Issuance' 'Defined Pension Benefit'
#  'Receivables Adjustments Allowances' 'Change In Other Current Assets'
#  'Change In Other Current Liabilities' 'Change In Payable'
#  'Change In Receivables' 'Change In Working Capital' 'Interest Paid Cfo'
#  'Interest Received Cfo' 'Taxes Refund Paid' 'Preferred Stock Dividends'
#  'Liabilities Heldfor Sale Non Current' 'Dividends Received Direct'
#  'Dividends Paid Direct' 'Preferred Shares Number'
#  'Change In Accrued Expense' 'Net Foreign Currency Exchange Gain Loss'
#  'Cash Flow From Continuing Financing Activities'
#  'Cash Flow From Continuing Investing Activities'
#  'Current Accrued Expenses' 'Current Deferred Liabilities'
#  'Current Deferred Revenue'
#  'Depreciation Amortization Depletion Income Statement'
#  'Earnings From Equity Interest' 'Employee Benefits'
#  'Gains Losses Not Affecting Retained Earnings' 'Income Tax Payable'
#  'Interest Payable' 'Leases' 'Line Of Credit'
#  'Non Current Accounts Receivable' 'Non Current Deferred Liabilities'
#  'Other Current Borrowings' 'Other Equity Adjustments' 'Other Gand A'
#  'Payables And Accrued Expenses' 'Provision For Doubtful Accounts'
#  'Salaries And Wages']
# ['BS' 'IS' 'CF']

# %% [markdown]
# Pada Setiap kolom terlihat bahwa format penulisan sudah konsisten. Seluruh data menggunakan format yang sama tanpa perbedaan huruf besar/kecil yang tidak perlu, sehingga tidak ditemukan kategori ganda dengan makna yang sama.
#
# Apabila adanya ketidak konsistenan dalam kolom kita dapat melakukan penanganan seperti
#
# df['Kolom'] = df['Kolom'].str.upper()

# %% [markdown]
# ### **Outliers**

# %% [markdown]
# Outlier merupakan nilai dalam suatu dataset yang memiliki perbedaan sangat jauh dibandingkan sebagian besar data lainnya. Nilai ini biasanya tampak terlalu tinggi atau terlalu rendah dari pola umum yang terbentuk, sehingga dapat memengaruhi hasil analisis, khususnya pada perhitungan statistik seperti rata-rata dan standar deviasi.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

#Dataframe dari list hasil

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

#Tampilkan dataframe

display(results_df)
# Out:
# Kolom  Persentase Outliers
# 2020             22.908239
# 2021             20.555114
# 2022             20.661564
# 2023              6.158466

# %% [markdown]
# dan terlihat bahwa:
# 1. pada kolom 2020 terdapat outliers sebesar 22,9%
# 2. oada kolom 2021 terdapat outliers sebesar 20,5%
# 3. pada kolom 2022 terdapat outliers sebesar 20,6%
# 4. pada kolom 2023 terdapat outliers sebesar 6.1%
#
# maka perlu dilakukan tindakan lebih lanjut seperti dibawah ini:

# %%
columns_to_impute = ["2020", "2021","2022","2023"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

#Dataframe dari list hasil

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

#Tampilkan dataframe

display(results_df)
# Out:
# Kolom  Persentase Outliers
# 2020                   0.0
# 2021                   0.0
# 2022                   0.0
# 2023                   0.0

# %% [markdown]
# Setelah dilakuan perbaikan pada kolom 2020-2023 maka kolom siap di gunakan untuk analisis lebih lanjut

# %% [markdown]
# ### **Penjelas singankat atau keputusan yang harusnya diambil pada bagian Outliers**

# %% [markdown]
# di karena dataset ini merupakan data laporan keuangan perusahaan dengan perbedaan skala aset dan pendapatan yang sangat signifikan nilai ekstrem tersebut kemungkinan besar merepresentasikan kondisi riil perusahaan besar dan bukan merupakan kesalahan pencatatan data Oleh karena itu outliers tidak dihapus melainkan dipertahankan agar tidak menghilangkan informasi penting dalam analisis keuangan

# %% [markdown]
# ### **Construct Data**

# %% [markdown]
# Tahap ini dilakukan dengan menambahkan kolom baru yang masih berhubungan dengan data sebelumnya, sehingga informasi yang dihasilkan tetap saling berkaitan dan lebih mudah digunakan dalam proses analisis.

# %% [markdown]
# Pembuatan kolom baru seperti "profit_margin, dan status_laba" dilakukan untuk meningkatkan kualitas analisis terhadap kinerja keuangan perusahaan. Kolom profit_margin digunakan untuk mengukur tingkat profitabilitas perusahaan secara proporsional, sedangkan kolom status_laba dibuat untuk mengelompokkan perusahaan ke dalam kategori Untung, Rugi, atau Break Even berdasarkan nilai laba bersihnya. Dengan adanya kolom-kolom baru ini, analisis menjadi lebih terarah serta memudahkan dalam mengidentifikasi pola dan perbandingan antar perusahaan.

# %%
def kategori_laba(x):
    if pd.isna(x):
        return 'Tidak Diketahui'
    elif x > 0:
        return 'Untung'
    elif x < 0:
        return 'Rugi'
    else:
        return 'Break Even'
df['status_laba_2023'] = pd.NA
df.loc[df['account'] == 'Net Income', 'status_laba_2023'] = df.loc[df['account'] == 'Net Income', '2023'].apply(kategori_laba)

# %% [markdown]
# Setelah menambahkan kolom kita dapat mengecek kolom apakah sudah menambah atau belum

# %%
print(df.columns)
# Out:
# Index(['symbol', 'account', 'type', '2023', 'katagori_profit',
#        'status_laba_2023'],
#       dtype='object')

# %% [markdown]
# Dapat dilihat kolom baru yang kita buat "katagori_profit dan status_laba_2023" sudah terlihat yang berarti kolom berhasil ditambahkan.

# %% [markdown]
# ### **Data Reduction**

# %% [markdown]
# pada tahap ini kita akan menghapus kolom yang dirasa kurang perlu untuk di analisis, agar memudahkan dalam menganalisa dan terlihat lebih rapi. tetapi kita akan membuat contoh untuk kolom-kolom yang akan di hapus seperti berikut

# %%
df = df.drop('2020', axis=1)
df = df.drop('2021', axis=1)
df = df.drop('2022', axis=1)

# %% [markdown]
# Kolom tahun 2020–2022 dihapus karena fokus analisis hanya pada kinerja keuangan tahun 2023. Kolom tersebut tidak digunakan dalam proses penentuan status laba tahun 2023 sehingga keberadaannya tidak memberikan kontribusi langsung terhadap tujuan analisis. Penghapusan kolom ini tidak memengaruhi hasil evaluasi untung atau rugi perusahaan, karena penentuan kategori laba sepenuhnya didasarkan pada nilai Net Income tahun 2023.

# %%
df[df['account'] == 'Net Income'][['symbol', 'type','2023','status_laba_2023']].head()
# Out:
#     symbol type          2023 status_laba_2023
# 70    AALI   IS  1.055897e+12           Untung
# 225   ABBA   IS -4.370504e+10             Rugi
# 359   ABDA   IS  8.458131e+10           Untung
# 492   ABMM   IS  2.890006e+08           Untung
# 662   ACES   IS  7.635075e+11           Untung

# %% [markdown]
# Dari sini terlihat kalau kolom yang ditampilkan memang hanya yang paling dibutuhkan untuk analisis, sedangkan yang tidak relevan sudah dihapus supaya datanya lebih rapi dan enak dibaca. Datanya juga sudah bersih dari nilai kosong atau duplikasi sehingga hasil analisis bisa lebih jelas.

# %% [markdown]
# # **Checkpoint 4**

# %% [markdown]
# ## **Bar Chart**

# %% [markdown]
# Bar chart digunakan untuk membandingkan jumlah data berdasarkan tipe laporan keuangan pada dataset.

# %%
top3type = df['type'].value_counts().head(5).sort_values(ascending=False) # head() jumlah yang mau ditampilkan & Urutan

plt.figure(figsize=(10, 6)) # Ukuran
plt.bar(top3type.index, top3type.values, color='indigo') # color warna
plt.xlabel('Type Laporan Keuangan') # keterangan X label
plt.ylabel('Jumlah data') # keterangan y label
plt.title('Top 3 tipe data laporan keuangan pada tahun 2023') # Judul
plt.xticks(rotation=45, ha='right') # rotasi teks
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Pie Chart**

# %% [markdown]
# Pie chart digunakan untuk melihat semua proporsi status laba perusahaan pada tahun 2023.

# %%
# Filter the DataFrame to get only 'Net Income' accounts
net_income_data = df[df['account'] == 'Net Income']

plt.figure(figsize=(10,6)) # ukuran

plt.pie(
    net_income_data['status_laba_2023'].value_counts(),
    labels=net_income_data['status_laba_2023'].value_counts().index,
    autopct='%1.1f%%',
    colors=['lightgreen','lightcoral','gold']
)

plt.title('Semua Proporsi Status Laba Perusahaan Tahun 2023') # Judul
plt.show()

# %% [markdown]
# ## **Line chart**

# %% [markdown]
# Line chart digunakan untuk melihat tren nilai laporan keuangan perusahaan dari tahun 2020 hingga 2023.

# %%
net_income = df[df['account'] == 'Net Income'][['symbol','2023']].dropna()
net_income = net_income.sort_values(by='2023', ascending=False).head(20)
plt.figure(figsize=(20,6))
plt.plot(net_income['symbol'], net_income['2023'], marker='o', color='indigo')
plt.title('Tren Laba Bersih Perusahaan Tahun 2023', fontsize=16)
plt.xlabel('Perusahaan', fontsize=12)
plt.ylabel('Net Income 2023', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **ScatterPlot**

# %% [markdown]
# Scatter plot digunakan untuk melihat hubungan nilai Net Income perusahaan yang mengalami ke untungan atau rugi pada tahun 2023

# %%
plt.figure(figsize=(20, 6)) # Ukuran
sns.scatterplot(x='symbol', y='2023', hue='status_laba_2023', data=df)
plt.title('Net Income Perusahaan Tahun 2023 Berdasarkan Status Laba') # Judul
plt.xlabel('Perusahaan') # X Keterangan
plt.ylabel('Net Income 2023') # Y Keterangan
plt.legend(title='Status Laba 2023') # Keterangan dalam kotak kecil
plt.show()

# %% [markdown]
# **Insight:** Berdasarkan visualisasi, sebagian besar perusahaan pada tahun 2023 memiliki Net Income positif sehingga tergolong dalam kategori untung. Namun masih terdapat beberapa perusahaan yang mengalami kerugian.
#
# **Tindakan:** Perusahaan yang mengalami kerugian perlu mengevaluasi strategi operasional dan pengelolaan biaya agar dapat meningkatkan kinerja keuangan di tahun berikutnya.

# %% [markdown]
# ### **Menyimpan Dataset**

# %%
df.to_csv('Check Point 3 MUAHAMMAD RISKY ALPIANUR 2509116101 C', index=False)
